# %% [markdown]
# ## Практическое задание к уроку 9: "Производная функции нескольких переменных. Часть 2"

# %% [markdown]
# **1. Исследовать функцию на условный экстремум.**

# %% [markdown]
# $U = 3 - 8x + 6y$, если $x^2 + y^2 = 36$

# %% [markdown]
# $L(\lambda_1, x, y) =  3 - 8x + 6y + \lambda_1 \cdot (x^2 + y^2 - 36)\\
# \begin{cases}
# L'_x = -8 + \lambda_1 \cdot 2x = 0 \\
# L'_y = 6 + \lambda_1 \cdot 2y = 0 \\
# L'_{\lambda_1} = x^2 + y^2 - 36 = 0 \\
# \end{cases} \\
# \begin{cases}
# x = \frac{8}{2\lambda_1} = \frac{4}{\lambda_1}\\
# L'_y = -\frac{6}{2\lambda_1} = -\frac{3}{\lambda_1} \\
# L'_{\lambda_1} = (\frac{4}{\lambda_1})^2 + (-\frac{3}{\lambda_1})^2 = 36 \\
# \end{cases} \\
# \begin{cases}
# x = \frac{4}{\lambda_1}\\
# L'_y = -\frac{3}{\lambda_1} \\
# L'_{\lambda_1} = \pm \frac{5}{6}\\
# \end{cases} \\
# \left (\frac{5}{6}, 4,8, -3,6 \right) \left (-\frac{5}{6}, -4,8, 3,6 \right) \\
# L''_{xx} = 2\lambda_1\\
# L''_{yy} = 2\lambda_1\\
# L''_{\lambda_1 \lambda_1} = 0\\
# L''_{xy} = 0\\
# L''_{x\lambda_1} = 2x\\
# L''_{y\lambda_1} = 2y\\
# \begin{pmatrix}
# L''_{\lambda_1 \lambda_1} & L''_{\lambda_1 x} & L''_{\lambda_1 y} \\
# L''_{x \lambda_1} & L''_{xx} & L''_{xy} \\
# L''_{y \lambda_1} & L''_{yx} & L''_{yy}
# \end{pmatrix} =
# \begin{pmatrix}
# 0 & 2x & 2y \\
# 2x & 2\lambda_1 & 0 \\
# 2y & 0 & 2\lambda_1
# \end{pmatrix} \\
# \begin{vmatrix}
# 0 & 2x & 2y \\
# 2x & 2\lambda_1 & 0 \\
# 2y & 0 & 2\lambda_1
# \end{vmatrix} = \\
# = 0 \cdot
# \begin{vmatrix}
# 2\lambda_1 & 0 \\
# 0 & 2\lambda_1
# \end{vmatrix}
# -2x \cdot
# \begin{vmatrix}
# 2x & 0 \\
# 2y & 2\lambda_1
# \end{vmatrix}
# +2y \cdot
# \begin{vmatrix}
# 2x & 2\lambda_1 \\
# 2y & 0
# \end{vmatrix} = \\
# = 0 - 2x \cdot (2x \cdot 2\lambda_1 - 0) + 2y \cdot (0 - 2y \cdot 2\lambda_1) = -8\lambda_1 \cdot (x^2 + y^2) \\
# \text{Т.к. знак определителя зависит только от $\lambda_1$, то} \\
# \left (\frac{5}{6}, 4.8, -3.6 \right), \Delta_1 = -240 < 0 \implies \text{точка минимума} \\
# \left (-\frac{5}{6}, -4.8, 3.6 \right), \Delta_1 = 240 > 0 \implies \text{точка максимума}
# $

# %% [markdown]
# **2. Исследовать функцию на условный экстремум.**

# %% [markdown]
# $2x^2 + 12xy +32y^2+15$, если $x^2 + 16y^2 = 64$

# %% [markdown]
# $
# L(\lambda_1, x, y) = 2x^2 + 12xy +32y^2 + 15 + \lambda_1 \cdot (x^2 + 16y^2  - 64) \\
# \begin{cases}
#   L'_x = 4x + 12y + 2\lambda_1x  = 0 \\
#   L'_y = 12x + 64y + 32\lambda_1y = 0 \\
#   L'_{\lambda_1} = x^2 + 16y^2  - 64 = 0
# \end{cases} \\
# \begin{cases}
#   2x + 6y + \lambda_1x  = 0 \\
#   3x + 16y + 8\lambda_1y = 0 \\
#   x^2 + 16y^2  - 64 = 0
# \end{cases} \\
# \begin{cases}
#   x \cdot (2 +  \lambda_1) + 6y = 0 \\
#   8y \cdot (2 + \lambda_1) + 3x = 0 \\
#   x^2 + 16y^2  - 64 = 0
# \end{cases} \\
# $
# Из II-го уравнения выразим $2 + \lambda_1$ и подставим в I-е:
# $
# \begin{cases}
#   x(-\frac{3x}{8y}) + 6y = 0 \\
#   2 + \lambda_1 = -\frac{3x}{8y} \\
#   x^2 + 16y^2 = 64
# \end{cases} \\
# \begin{cases}
#   -\frac{3x^2}{8y} = -6y \\
#   2 + \lambda_1 = -\frac{3x}{8y} \\
#   x^2 + 16y^2 = 64
# \end{cases} \\
# \begin{cases}
#   3x^2 = 48y^2 \\
#   2 + \lambda_1 = -\frac{3x}{8y} \\
#   x^2 + 16y^2 = 64
# \end{cases} \\
# \begin{cases}
#   x^2 = 16y^2 \\
#   2 + \lambda_1 = -\frac{3x}{8y} \\
#   x^2 + x^2 = 64
# \end{cases} \\
# \begin{cases}
#   x^2 = 16y^2 \\
#   2 + \lambda_1 = -\frac{3x}{8y} \\
#   x^2 = 32
# \end{cases} \\
# \begin{cases}
#   x^2 = 16y^2 \\
#   2 + \lambda_1 = -\frac{3x}{8y} \\
#   x = \pm 4\sqrt{2}
# \end{cases} \\
# \begin{cases}
#   y = \pm\sqrt{2} \\
#   2 + \lambda_1 = -\frac{3x}{8y} \\
#   x = \pm 4\sqrt{2}
# \end{cases} \\
# $
#
# Подставляя полученные значения x и y во-второе уравнение системы, получаем следующие значения $\lambda_1$:
#
# $\begin{array}{|l}
#     \left(- 0.5, 4\sqrt{2}, -\sqrt{2} \right) \\
#     \left(- 3.5, 4\sqrt{2}, \sqrt{2} \right) \\
#     \left(- 3.5, -4\sqrt{2}, -\sqrt{2} \right) \\
#     \left(- 0.5, -4\sqrt{2}, \sqrt{2} \right) \\
# \end{array} \\
# L''_{xx} = 2\lambda_1 + 4 \\
# L''_{yy} =32\lambda_1 + 64 \\
# L''_{\lambda_1\lambda_1} = 0 \\
# L''_{xy} = 12 \\
# L''_{x\lambda_1} = 2x \\
# L''_{y\lambda_1} = 32y \\
# \begin{pmatrix}
#     L''_{\lambda_1\lambda_1} & L''_{\lambda_1 x} & L''_{\lambda_1 y} \\
#     L''_{x \lambda_1} & L''_{xx} & L''_{xy} \\
#     L''_{y \lambda_1} & L''{yx} & L''{yy}
# \end{pmatrix} =
# \begin{pmatrix}
#   0 & 2x & 32y\\
#   2x & 2\lambda_1 + 4 & 12\\
#   32y & 12 & 32\lambda_1 + 64
# \end{pmatrix} \\
# \begin{vmatrix}
#   0 & 2x & 32y\\
#   2x & 2\lambda_1 + 4 & 12\\
#   32y & 12 & 32\lambda_1 + 64
# \end{vmatrix} = \\
# = 0 \cdot
# \begin{vmatrix}
# 2\lambda_1 + 4 & 12 \\
# 12 & 32\lambda_1 + 64
# \end{vmatrix}
# -2x \cdot
# \begin{vmatrix}
# 2x & 12 \\
# 32y & 32\lambda_1 + 64
# \end{vmatrix}
# +32y \cdot
# \begin{vmatrix}
# 2x & 2\lambda_1 + 4 \\
# 32y & 12
# \end{vmatrix} = \\
# = -128 x^2 \lambda_1-256x^2 + 1536xy - 2048y^2\lambda_1 -4096y^2 = -256(x^2 + 16y^2) - 128\lambda_1(x^2 + 16y^2) + 1536xy = -256 \cdot 64 - 128\lambda_1 \cdot 64 + 1536xy = -16384 - 8192\lambda_1 + 1536xy \\
# $
# При любых x и y $(x^2 + 16y^2)$  будет равно 64. $\lambda_1$ ыезде отрицательная. Поэтому знак определителя зависит только от произведения x и y:
# $
# \left(- 0.5, 4\sqrt{2}, -\sqrt{2} \right), \Delta_1 = -29665.86 < 0 \implies \text{точка минимума} \\
# \left(- 3.5, 4\sqrt{2}, \sqrt{2} \right), \Delta_1 = 29665.86 > 0 \implies \text{точка максимума} \\
# \left(- 3.5, -4\sqrt{2}, -\sqrt{2} \right), \Delta_1 = 29665.86 > 0 \implies \text{точка максимума} \\
# \left(- 0.5, -4\sqrt{2}, \sqrt{2} \right), \Delta_1 = -29665.86 < 0 \implies \text{точка минимума} \\
# $

# %% [markdown]
# **3. Найти производную функции $U = x^2 + y^2 + z^2$ понаправлению вектора $\vec{c}(-9,8,-12)$ в точке M(8;-12;9).**

# %% [markdown]
# $|\vec{c}| = \sqrt{-9^2 + 8^2 + (-12)^2} = \sqrt{289} = 17 \\
# \vec{c_0} = \frac{\vec{c}}{|\vec{c}|} = \left(-\frac{9}{17}; \frac{8}{17}; -\frac{12}{17}\right) \\
# U = x^2 + y^2 + z^2 \\
# U'_x = 2x \\
# U'_y = 2y \\
# U'_z = 2z \\
# \mathrm{grad}\ U = (U'_x, U'_y, U'_z) = (2x, 2y, 2z) \\
# \mathrm{grad}\ U|_M = (16, -24, 18) \\
# U'_{\vec{c}}|_M = 16 \cdot (-\frac{9}{17}) - 24 \cdot (\frac{8}{17}) + 18 \cdot (-\frac{12}{17}) = -\frac{552}{17}\\
# $

# %% [markdown]
# **4. Найти производную функции $U = e^{x^2 + y^2 + z^2}$ понаправлению вектора $\vec{d}(4,-13,-16)$ в точке L(-16;4;-13).**

# %% [markdown]
# $|\vec{d}| = \sqrt{4^2 + (-13)^2 + (-16)^2} = \sqrt{441} = 21 \\
# \vec{d_0} = \frac{\vec{d}}{|\vec{d}|} = (\frac{4}{21}; -\frac{13}{21}; -\frac{16}{21}) \\
# U = e^{x^2 + y^2 + z^2} \\
# U'_x = e^{x^2 + y^2 + z^2} \cdot 2x \\
# U'_y = e^{x^2 + y^2 + z^2} \cdot 2y \\
# U'_z = e^{x^2 + y^2 + z^2} \cdot 2z \\
# \mathrm{grad}\ U = (U'_x, U'_y, U'_z) = (2x \cdot e^{x^2 + y^2 + z^2}, 2y \cdot e^{x^2 + y^2 + z^2}, 2z \cdot e^{x^2 + y^2 + z^2}) \\
# U'_x(L) = 2x \cdot e^{x^2 + y^2 + z^2} = 2 \cdot (-16) \cdot e^{(-16)^2 + (4)^2 + (-13)^2} = -32 \cdot e^{441}\\
# U'_y(L) = 2y \cdot e^{x^2 + y^2 + z^2} = 2 \cdot 4 \cdot e^{(-16)^2 + (4)^2 + (-13)^2} = 8 \cdot e^{441}\\
# U'_z(L) = 2z \cdot e^{x^2 + y^2 + z^2} = 2 \cdot (-13) \cdot e^{(-16)^2 + (4)^2 + (-13)^2} = -26 \cdot e^{441}\\
# \mathrm{grad}\ U|_L = (-32 \cdot e^{441}, 8 \cdot e^{441}, -26 \cdot e^{441}) \\
# U'_{\vec{c}}|_L = (-32 \cdot e^{441}) \cdot (\frac{4}{21}) + (8 \cdot e^{441}) \cdot (-\frac{13}{21}) + (-26 \cdot e^{441}) \cdot (-\frac{16}{21}) = e^{441} \cdot(-32 \cdot (\frac{4}{21}) + (8 \cdot (-\frac{13}{21}) + (-26 \cdot (-\frac{16}{21}) = e^{441} \cdot(-\frac{128}{21} -\frac{104}{21} +\frac{416}{21}) = (\frac{184}{21}) \cdot e^{441} \\
# $
